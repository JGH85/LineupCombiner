# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import csv
from io import StringIO

# %%
url = 'https://www.espn.com/fantasy/football/insider/story/_/id/27537617/nfl-dfs-picks-your-week-15-fanduel-lineups'

# %%
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(response.text, 'html.parser')

# %%
# print(soup.prettify())

# %%
# results = soup.find_all('aside')
# results
# Out:
# [<aside class="inline editorial float-r" data-behavior="article_related"><h1>Editor's Picks</h1><ul><li><a class="img-link" href="/fantasy/football/insider/story/_/id/28274107/fantasy-football-shadow-report-key-wr-cb-matchups-week-15" name="&amp;lpos=story:editorspicks:inline:1"><img src="https://a.espncdn.com/combiner/i?img=/photo/2019/1211/r640083_1296x1296_1-1.jpg&amp;w=130&amp;h=130&amp;scale=crop&amp;location=center"/></a><h2><a class="espnplus" href="/fantasy/football/insider/story/_/id/28274107/fantasy-football-shadow-report-key-wr-cb-matchups-week-15" name="&amp;lpos=story:editorspicks:inline:1">Shadow Report: Key WR/CB matchups for Week 15</a></h2></li><li><a class="img-link" href="/fantasy/football/story/_/page/consistency2019/fantasy-football-consistency-ratings-2019" name="&amp;lpos=story:editorspicks:inline:2"><img src="https://a.espncdn.com/combiner/i?img=/photo/2019/1001/r606490_1296x1296_1-1.jpg&amp;w=130&amp;h=130&amp;scale=crop&amp;location=center"/></a><h2><a class
# ...

# %%
# this isn't going to get what i want without adding authentication

# %%
filename = 'fd_dk_Best_plays.xlsx'

# %%
pd.read_excel(filename, sheet_name="FD_QB")
# Out:
#    Quarterbacks For FanDuel Week 15 Main Slate Unnamed: 1 Unnamed: 2  \
# 0                                       PLAYER     RATING       TEAM
# 1                              Jimmy Garoppolo    Average         SF
# 2                              Patrick Mahomes    Average         KC
# 3                               Jameis Winston      Great         TB
# 4                               Deshaun Watson      Great        HOU
# 5                               Russell Wilson       Good        SEA
# 6                                Aaron Rodgers    Average         GB
# 7                                 Kirk Cousins      Shaky        MIN
# 8                                   Jared Goff       Poor        LAR
# 9                                 Dak Prescott    Average        DAL
# 10                              Baker Mayfield    Average        CLE
# 11                                Carson Wentz    Average        PHI
# 12                                   Matt Ryan      Shaky        ATL
# ...
