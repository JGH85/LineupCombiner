# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import csv
from io import StringIO

# %%
# url = 'http://rotoguru1.com/cgi-bin/fyday.pl?week=1&game=fd&scsv=1'

# %%
# response = requests.get(url)

# %%
# # Create BeautifulSoup object; parse with 'html.parser'
# soup = bs(response.text, 'html.parser')

# %%
# print(soup.prettify())

# %%
# results = soup.find_all('pre')
# # results

# %%
# r = str(results[0])
# type(r)

# %%
# r

# %%
# results_to_process = r[5:]
# results_to_process = results_to_process[:-6]
# # results_to_process

# %%
# # try using csv reader to parse string from beautiful soup
# test = csv.reader(r, delimiter=';')
# for row in test:
#     print(row)
# #     print("next line")

# %%
# # try using csv reader to parse string from beautiful soup
# csvstring = StringIO(results_to_process)
# test = csv.reader(csvstring, delimiter=';')
# for row in test:
#     print(row)
# #     print("next line")

# %%
# # try using csv reader to parse string from beautiful soup
# csvstring2 = StringIO(results_to_process)
# df = pd.read_csv(csvstring2, sep=';')
# df.head()

# %% [markdown]
# # Setup Function to import from url to dataframe

# %%
def url_to_dataframe(url):
    print(url)
    response = requests.get(url)
    # Create BeautifulSoup object; parse with 'html.parser'
    soup = bs(response.text, 'html.parser')
    results = soup.find_all('pre')
    r = str(results[0])
    results_to_process = r[5:]
    results_to_process = results_to_process[:-6]
    csvstring2 = StringIO(results_to_process)
    df_to_return = pd.read_csv(csvstring2, sep=';')
#     print(df_to_return.head())
    return df_to_return

# %% [markdown]
# # Setup URLs

# %%
# setup urls
base_url = 'http://rotoguru1.com/cgi-bin/fyday.pl?'
fd_search = 'scsv=1&game=fd'
dk_search = 'scsv=1&game=dk'
year_query = '&year='
week_query = '&week='

# %% [markdown]
# # Create list of urls for FD and DK

# %%
url_list_fd = []
year = '2019'
for i in range (1,18):
    combined_url = base_url + fd_search + year_query + year + week_query + str(i)
    print(combined_url)
    url_list_fd.append(combined_url)

url_list_dk = []
for i in range (1,18):
    combined_url = base_url + dk_search + year_query + year + week_query + str(i)
    print(combined_url)
    url_list_dk.append(combined_url)
# Out:
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=1
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=2
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=3
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=4
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=5
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=6
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=7
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=8
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=9
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=10
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=11
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=12
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=13
# ...

# %% [markdown]
# # Import from URLs to dataframes

# %%
master_df_fd = pd.DataFrame()

for u in url_list_fd:
    temp_df = url_to_dataframe(u)
    master_df_fd = master_df_fd.append(temp_df)
# Out:
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=1
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=2
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=3
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=4
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=5
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=6
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=7
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=8
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=9
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=10
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=11
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=12
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=fd&year=2019&week=13
# ...

# %%
master_df_dk = pd.DataFrame()

for u in url_list_dk:
    temp_df = url_to_dataframe(u)
    master_df_dk = master_df_dk.append(temp_df)
# Out:
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=1
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=2
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=3
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=4
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=5
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=6
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=7
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=8
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=9
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=10
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=11
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=12
# http://rotoguru1.com/cgi-bin/fyday.pl?scsv=1&game=dk&year=2019&week=13
# ...

# %%
master_df_dk.head()
# Out:
#    Week  Year   GID                 Name Pos Team h/a Oppt  DK points  \
# 0     1  2019  1527       Jackson, Lamar  QB  bal   a  mia      36.56
# 1     1  2019  1501        Prescott, Dak  QB  dal   h  nyg      36.40
# 2     1  2019  1518      Watson, Deshaun  QB  hou   a  nor      31.72
# 3     1  2019  1340    Stafford, Matthew  QB  det   a  ari      31.60
# 4     1  2019  1523  Mahomes II, Patrick  QB  kan   a  jac      30.32
#
#    DK salary
# 0     6000.0
# 1     5900.0
# 2     6800.0
# 3     5400.0
# 4     7200.0

# %% [markdown]
# # Clean up and join dataframes

# %%
# add dk suffix
master_df_dk = master_df_dk.add_suffix('_dk')
master_df_dk.head()
# Out:
#    Week_dk  Year_dk  GID_dk              Name_dk Pos_dk Team_dk h/a_dk  \
# 0        1     2019    1527       Jackson, Lamar     QB     bal      a
# 1        1     2019    1501        Prescott, Dak     QB     dal      h
# 2        1     2019    1518      Watson, Deshaun     QB     hou      a
# 3        1     2019    1340    Stafford, Matthew     QB     det      a
# 4        1     2019    1523  Mahomes II, Patrick     QB     kan      a
#
#   Oppt_dk  DK points_dk  DK salary_dk
# 0     mia         36.56        6000.0
# 1     nyg         36.40        5900.0
# 2     nor         31.72        6800.0
# 3     ari         31.60        5400.0
# 4     jac         30.32        7200.0

# %%
# master_df_dk.sort_values(by=['GID_dk'])

# %%
master_df_fd = master_df_fd.add_suffix('_fd')

master_df_fd.head()
# Out:
#    Week_fd  Year_fd  GID_fd              Name_fd Pos_fd Team_fd h/a_fd  \
# 0        1     2019    1527       Jackson, Lamar     QB     bal      a
# 1        1     2019    1501        Prescott, Dak     QB     dal      h
# 2        1     2019    1518      Watson, Deshaun     QB     hou      a
# 3        1     2019    1340    Stafford, Matthew     QB     det      a
# 4        1     2019    1523  Mahomes II, Patrick     QB     kan      a
#
#   Oppt_fd  FD points_fd  FD salary_fd
# 0     mia         33.56        7400.0
# 1     nyg         33.40        7500.0
# 2     nor         31.72        8500.0
# 3     ari         27.60        6600.0
# 4     jac         27.32        8700.0

# %%
master_df_fd.sort_values(by=['GID_fd'])
# Out:
#      Week_fd  Year_fd  GID_fd       Name_fd Pos_fd Team_fd h/a_fd Oppt_fd  \
# 12         3     2019    1131    Brady, Tom     QB     nwe      h     nyj
# 18         7     2019    1131    Brady, Tom     QB     nwe      a     nyj
# 25        14     2019    1131    Brady, Tom     QB     nwe      h     kan
# 16        12     2019    1131    Brady, Tom     QB     nwe      h     dal
# 23        15     2019    1131    Brady, Tom     QB     nwe      a     cin
# 4         13     2019    1131    Brady, Tom     QB     nwe      a     hou
# 6          6     2019    1131    Brady, Tom     QB     nwe      h     nyg
# 12         8     2019    1131    Brady, Tom     QB     nwe      h     cle
# 19         9     2019    1131    Brady, Tom     QB     nwe      a     bal
# 24        11     2019    1131    Brady, Tom     QB     nwe      a     phi
# 6          1     2019    1131    Brady, Tom     QB     nwe      h     pit
# 12        16     2019    1131    Brady, Tom     QB     nwe      h     buf
# ...

# %%
all_year = pd.merge(master_df_dk, master_df_fd, 'outer', left_on =['GID_dk', 'Week_dk'], right_on = ['GID_fd', 'Week_fd'])
all_year.head()
# Out:
#    Week_dk  Year_dk  GID_dk              Name_dk Pos_dk Team_dk h/a_dk  \
# 0      1.0   2019.0  1527.0       Jackson, Lamar     QB     bal      a
# 1      1.0   2019.0  1501.0        Prescott, Dak     QB     dal      h
# 2      1.0   2019.0  1518.0      Watson, Deshaun     QB     hou      a
# 3      1.0   2019.0  1340.0    Stafford, Matthew     QB     det      a
# 4      1.0   2019.0  1523.0  Mahomes II, Patrick     QB     kan      a
#
#   Oppt_dk  DK points_dk  DK salary_dk  Week_fd  Year_fd  GID_fd  \
# 0     mia         36.56        6000.0      1.0   2019.0  1527.0
# 1     nyg         36.40        5900.0      1.0   2019.0  1501.0
# 2     nor         31.72        6800.0      1.0   2019.0  1518.0
# 3     ari         31.60        5400.0      1.0   2019.0  1340.0
# 4     jac         30.32        7200.0      1.0   2019.0  1523.0
#
#                Name_fd Pos_fd Team_fd h/a_fd Oppt_fd  FD points_fd  \
# 0       Jackson, Lamar     QB     bal      a     mia         33.56
# ...

# %%
len(master_df_dk)
# Out:
# 6810

# %%
len(master_df_fd)
# Out:
# 7250

# %%
len(all_year)
# Out:
# 7344

# %%
all_year.tail()
# Out:
#       Week_dk  Year_dk  GID_dk Name_dk Pos_dk Team_dk h/a_dk Oppt_dk  \
# 7339      NaN      NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 7340      NaN      NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 7341      NaN      NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 7342      NaN      NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 7343      NaN      NaN     NaN     NaN    NaN     NaN    NaN     NaN
#
#       DK points_dk  DK salary_dk  Week_fd  Year_fd  GID_fd            Name_fd  \
# 7339           NaN           NaN     17.0   2019.0  6437.0         Slye, Joey
# 7340           NaN           NaN     17.0   2019.0  6236.0       Myers, Jason
# 7341           NaN           NaN     17.0   2019.0  6432.0      Badgley, Mike
# 7342           NaN           NaN     17.0   2019.0  6241.0  Fairbairn, Ka'imi
# 7343           NaN           NaN     17.0   2019.0  6436.0          Gay, Matt
#
#      Pos_fd Team_fd h/a_fd Oppt_fd  FD points_fd  FD salary_fd
# ...

# %%
all_year['Name_dk'].fillna(all_year['Name_fd'], inplace = True)
all_year.tail()
# Out:
#       Week_dk  Year_dk  GID_dk            Name_dk Pos_dk Team_dk h/a_dk  \
# 7339      NaN      NaN     NaN         Slye, Joey    NaN     NaN    NaN
# 7340      NaN      NaN     NaN       Myers, Jason    NaN     NaN    NaN
# 7341      NaN      NaN     NaN      Badgley, Mike    NaN     NaN    NaN
# 7342      NaN      NaN     NaN  Fairbairn, Ka'imi    NaN     NaN    NaN
# 7343      NaN      NaN     NaN          Gay, Matt    NaN     NaN    NaN
#
#      Oppt_dk  DK points_dk  DK salary_dk  Week_fd  Year_fd  GID_fd  \
# 7339     NaN           NaN           NaN     17.0   2019.0  6437.0
# 7340     NaN           NaN           NaN     17.0   2019.0  6236.0
# 7341     NaN           NaN           NaN     17.0   2019.0  6432.0
# 7342     NaN           NaN           NaN     17.0   2019.0  6241.0
# 7343     NaN           NaN           NaN     17.0   2019.0  6436.0
#
#                 Name_fd Pos_fd Team_fd h/a_fd Oppt_fd  FD points_fd  \
# ...

# %%
all_year['Week_dk'].fillna(all_year['Week_fd'], inplace = True)
all_year['Year_dk'].fillna(all_year['Year_fd'], inplace = True)
all_year['GID_dk'].fillna(all_year['GID_fd'], inplace = True)
all_year['Pos_dk'].fillna(all_year['Pos_fd'], inplace = True)
all_year['Team_dk'].fillna(all_year['Team_fd'], inplace = True)
all_year['h/a_dk'].fillna(all_year['h/a_fd'], inplace = True)
all_year['Oppt_dk'].fillna(all_year['Oppt_fd'], inplace = True)

all_year['Name_fd'].fillna(all_year['Name_dk'], inplace = True)
all_year['Week_fd'].fillna(all_year['Week_dk'], inplace = True)
all_year['Year_fd'].fillna(all_year['Year_dk'], inplace = True)
all_year['GID_fd'].fillna(all_year['GID_dk'], inplace = True)
all_year['Pos_fd'].fillna(all_year['Pos_dk'], inplace = True)
all_year['Team_fd'].fillna(all_year['Team_dk'], inplace = True)
all_year['h/a_fd'].fillna(all_year['h/a_dk'], inplace = True)
all_year['Oppt_fd'].fillna(all_year['Oppt_dk'], inplace = True)

all_year.tail()
# Out:
#       Week_dk  Year_dk  GID_dk            Name_dk Pos_dk Team_dk h/a_dk  \
# 7339     17.0   2019.0  6437.0         Slye, Joey     PK     car      h
# 7340     17.0   2019.0  6236.0       Myers, Jason     PK     sea      h
# 7341     17.0   2019.0  6432.0      Badgley, Mike     PK     lac      a
# 7342     17.0   2019.0  6241.0  Fairbairn, Ka'imi     PK     hou      h
# 7343     17.0   2019.0  6436.0          Gay, Matt     PK     tam      h
#
#      Oppt_dk  DK points_dk  DK salary_dk  Week_fd  Year_fd  GID_fd  \
# 7339     nor           NaN           NaN     17.0   2019.0  6437.0
# 7340     sfo           NaN           NaN     17.0   2019.0  6236.0
# 7341     kan           NaN           NaN     17.0   2019.0  6432.0
# 7342     ten           NaN           NaN     17.0   2019.0  6241.0
# 7343     atl           NaN           NaN     17.0   2019.0  6436.0
#
#                 Name_fd Pos_fd Team_fd h/a_fd Oppt_fd  FD points_fd  \
# ...

# %%
all_year.columns.tolist()
# Out:
# ['Week_dk',
#  'Year_dk',
#  'GID_dk',
#  'Name_dk',
#  'Pos_dk',
#  'Team_dk',
#  'h/a_dk',
#  'Oppt_dk',
#  'DK points_dk',
#  'DK salary_dk',
#  'Week_fd',
#  'Year_fd',
#  'GID_fd',
#  'Name_fd',
#  'Pos_fd',
#  'Team_fd',
#  'h/a_fd',
#  'Oppt_fd',
#  'FD points_fd',
#  'FD salary_fd']

# %%
all_final = all_year[['Week_dk',
 'Year_dk',
 'GID_dk',
 'Name_dk',
 'Pos_dk',
 'Team_dk',
 'h/a_dk',
 'Oppt_dk',
 'DK points_dk',
 'DK salary_dk',
 'FD points_fd',
 'FD salary_fd']]

# %%
all_final.columns.tolist()
# Out:
# ['Week_dk',
#  'Year_dk',
#  'GID_dk',
#  'Name_dk',
#  'Pos_dk',
#  'Team_dk',
#  'h/a_dk',
#  'Oppt_dk',
#  'DK points_dk',
#  'DK salary_dk',
#  'FD points_fd',
#  'FD salary_fd']

# %%
# capital letters are a pain in postgres so get rid of them here
new_columns = ['week',
 'year',
 'gid',
 'name',
 'pos',
 'team',
 'h/a',
 'oppt',
 'dk_points',
 'dk_salary',
 'fd_points',
 'fd_salary']

# %%
all_final.columns = new_columns

# %%
all_final
# Out:
#       week    year     gid                 name pos team h/a oppt  dk_points  \
# 0      1.0  2019.0  1527.0       Jackson, Lamar  QB  bal   a  mia      36.56
# 1      1.0  2019.0  1501.0        Prescott, Dak  QB  dal   h  nyg      36.40
# 2      1.0  2019.0  1518.0      Watson, Deshaun  QB  hou   a  nor      31.72
# 3      1.0  2019.0  1340.0    Stafford, Matthew  QB  det   a  ari      31.60
# 4      1.0  2019.0  1523.0  Mahomes II, Patrick  QB  kan   a  jac      30.32
# 5      1.0  2019.0  1435.0         Keenum, Case  QB  was   a  phi      30.20
# 6      1.0  2019.0  1131.0           Brady, Tom  QB  nwe   h  pit      28.64
# 7      1.0  2019.0  1514.0        Wentz, Carson  QB  phi   h  was      28.02
# 8      1.0  2019.0  1231.0       Rivers, Philip  QB  lac   h  ind      27.92
# 9      1.0  2019.0  1403.0         Dalton, Andy  QB  cin   a  sea      25.72
# 10     1.0  2019.0  1537.0        Murray, Kyler  QB  ari   h  det      25.62
# ...

# %%
csv_name = year + "_fantasy_data_dk_and_fd.csv"
all_final.to_csv(csv_name)

# %%
#connect to sqlalchemy
from sqlalchemy import create_engine

# %%
db_string = 'postgresql://postgres:postgres@localhost:5432/fantasydata2018test'
db = create_engine(db_string)

# %%
db_table_name = "raw_data_" + year

# %%
all_final.to_sql(db_table_name, con=db)
